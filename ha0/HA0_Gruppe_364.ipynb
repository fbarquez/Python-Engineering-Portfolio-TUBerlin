# %% [markdown]
# # Technische Universität Berlin
# ## Python für Ingenieure - Hausaufgabe 0
#
# **Anmerkungen:**
# - Diese Abgabe dient dem Kennenlernen der Gruppenmitglieder
# - Grundlegende Programmierkonzepte werden angewendet
# - Format: Jupyter Notebook gemäß Aufgabenstellung

# %% [markdown]
# ## Aufgabe 1

# %% [markdown]
# ### Gruppe: 364
#
# |ID| Name | Matrikelnr. | TUB E-Mail | Studiengang |
# |-|:-----|:------------:|:-----------:|:------------|
# |**1**| Fernando Isaac Carlos Barriga Vasquez | 515561 | f.barriga.vasquez@campus.tu-berlin.de | Computer Engineering M.Sc. |
# |**2**| Imahnuka Chandrasegaran | 485902 | imahnuka.chandrasegaran@campus.tu-berlin.de | ??? |

# %% [markdown]
# ## Aufgabe 2

# %%
matrikelnr1 = 515561    # Matrikelnummer von Fernando Barriga Vasquez
matrikelnr2 = 485902    # Matrikelnummer von Imahnuka Chandrasegaran

differenz = abs(matrikelnr1 - matrikelnr2)
studenten_pro_semester = 2000
tage_pro_semester = 180    # ≈ 6 Monate

delta_t = (differenz / studenten_pro_semester) * tage_pro_semester

print(f"Unterschied in Matrikelnummern: {differenz}")
print(f"Zeit zwischen Einschreibungen: {delta_t:.1f} Tage")

# Variable für die Aufgabe benötigt
delta_t
# Out:
# Unterschied in Matrikelnummern: 29659
# Zeit zwischen Einschreibungen: 2669.3 Tage
# 2669.31

# %% [markdown]
# ## Aufgabe 3

# %%
gruppen_nummer = "364"
name1 = "FernandoIsaacCarlosBarrigaVasquez"          # Name ohne Leerzeichen
name2 = "ImahnukaChandrasegaran"

# BERECHNUNG
letzte_2_ziffern = gruppen_nummer[-2:]
ziffer1 = letzte_2_ziffern[0]
ziffer2 = letzte_2_ziffern[1]

teil1 = ziffer1 * len(name1)
teil2 = ziffer2 * len(name2)
zeichenkette = teil1 + teil2

print(f"Name 1: {name1} (Länge: {len(name1)})")
print(f"Name 2: {name2} (Länge: {len(name2)})")
print(f"Ergebniszeichenkette: {zeichenkette}")

# Variable für die Aufgabe benötigt
zeichenkette
# Out:
# Name 1: FernandoIsaacCarlosBarrigaVasquez (Länge: 33)
# Name 2: ImahnukaChandrasegaran (Länge: 22)
# Ergebniszeichenkette: 6666666666666666666666666666666664444444444444444444444
# '6666666666666666666666666666666664444444444444444444444'
